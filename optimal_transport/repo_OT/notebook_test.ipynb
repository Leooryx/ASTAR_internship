# %% [markdown]
# # Test for OT UDA repo

# %%
# !pip install wilds
# !pip install geomloss

# %%
from wilds import get_dataset
dataset = get_dataset(dataset="camelyon17", download=True)

# %%
# !python train_OT.py --exp 0 --Lambda .1 --batch_size 128
# Out:
# Namespace(epoch=0, n_epochs=5, ref_dataset=0, batch_size=128, lr=0.0001, Lambda=0.1, exp=0, b1=0.599, b2=0.9, n_cpu=16)
# Let's use 1 GPUs!
# /home/leolr-int/micromamba/envs/py312-poetry/lib/python3.12/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ...
