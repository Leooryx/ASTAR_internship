# %% [markdown]
# # Entire and modular pipeline

# %% [markdown]
# ## Steps:
#
# 0. Patch generation (not done here, see Eric's code)
# 1. Create deeplake dataset
# 2. Obtain embeddings (through chosen model) with storage
# 3. Linear probing
#
#
#
# Optional: Visualisation of embeddings

# %% [markdown]
# TODO: generate a code that connects embeddings and linear probing all at once without storage.
